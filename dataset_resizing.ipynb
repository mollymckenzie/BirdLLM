# %%
import pandas as pd 

df = pd.read_csv("0011360-260409193756587.csv", sep='\t')

# %%
#df.head()
df = df.drop(columns=['year', 'month','day', 'issue'], axis = 1)

list(df.columns.values)
# Out:
# ['gbifID',
#  'kingdom',
#  'phylum',
#  'class',
#  'order',
#  'family',
#  'genus',
#  'species',
#  'locality',
#  'individualCount',
#  'decimalLatitude',
#  'decimalLongitude',
#  'eventDate',
#  'taxonKey',
#  'speciesKey',
#  'catalogNumber',
#  'lastInterpreted']

# %%
df.to_csv("BirdLLM_dataset.csv", sep='\t')

# %%
df.head()
# Out:
#        gbifID   kingdom    phylum class            order        family  \
# 0  5554891251  Animalia  Chordata  Aves      Apodiformes   Trochilidae
# 1  3539588666  Animalia  Chordata  Aves    Passeriformes  Hirundinidae
# 2  3605760211  Animalia  Chordata  Aves     Anseriformes      Anatidae
# 3  4840476631  Animalia  Chordata  Aves    Passeriformes       Paridae
# 4  4710695977  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
#
#          genus               species  \
# 0  Archilochus  Archilochus colubris
# 1  Tachycineta   Tachycineta bicolor
# 2       Branta     Branta canadensis
# 3   Baeolophus    Baeolophus bicolor
# 4        Buteo        Buteo lineatus
#
#                                             locality  individualCount  \
# 0  US-TN-Knoxville-11931 Couch Mill Rd - 35.9390x...              2.0
# 1                   Seven Islands State Birding Park              4.0
# 2                                      Colonial Pond              1.0
# ...
